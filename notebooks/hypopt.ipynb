# %% [markdown]
# # Hyperparameter optimization with Optuna

# %% [markdown]
# ## Data

# %%
import numpy as np
from reservoirpy.datasets import lorenz, rossler
from rcpy.data.data_generation import ulam_map
from rcpy.data import preprocess_data_rcpy 


# ----- Generate data -----

system = "logistic_map"
r = 3.8
system_name = f"{system}_r{r}"
data_raw = np.load(f"../../../data/generated/ts_{system_name}.npy")

""" system = "nino"
years = "1870_2024"
system_name = f"{system}_{years}"
data_raw = np.loadtxt(f"../../../data/enso/ts_{system_name}.csv") """


#data_raw = ulam_map(x0=0.1, n_steps=10000, discard=1000)
#data_raw = lorenz(10000)
#data_raw = rossler(11000)[1000:,0]
#data_raw = np.load(f"../../../data/generated/ts_{system_name}.npy")


# ----- Preprocess data -----

# Parameters for preprocessing
offset = 0
train_length = 30000
val_length = 500

# Preprocess the raw data
data = preprocess_data_rcpy(
    data=data_raw,
    init_discard=offset,
    train_length=train_length,
    val_length=val_length,
    normalize=True
)

# %% [markdown]
# ## Hypopt

# %%
from rcpy.hypopt import build_objective, run_optimization, save_best_params, convert_numpy
import json

train_config = {
    "washout_training": 500
}

forecast_config = {
    "forecasting_step": 1,
    "warmup_length": 500
}

hypopt_config = {
    "trials": 100,
    "timeout_hours": 2,
    "save_db": False
}

loss_config = {
    "function": "soft_horizon",
    "threshold": 0.1,
    "softness": 0.02
}

leak_rate = 1
p = 0.1

hypopt_search_space = {
    "spectral_radius": {"range": [0.1, 2], "log": True},
    "leak_rate": {"fixed": leak_rate},
    "input_scaling": {"range": [0.01, 1], "log": False},
    "alpha": {"range": [1e-8, 1e-2], "log": True},
    "p": {"fixed": p}
}


optimization = {
    "config": hypopt_config,
    "loss": loss_config,
    "search_space": hypopt_search_space
}

seed = 42
reservoir_units = 500
study_name = "esn_hypopt_study"
#db_file = "esn_hypopt_study.db"
db_file = db_file = f"{study_name}.db" if optimization["config"]["save_db"]==True else None

objective_func = build_objective(
    data=data,
    reservoir_units=reservoir_units,
    seed=seed,
    hypopt_config=optimization,
    train_config=train_config,
    forecast_config=forecast_config,
)

study = run_optimization(
    study_name=study_name,
    db_file=db_file,
    objective_func=objective_func,
    hypopt_config=hypopt_config
)

print(f"Best loss: {study.best_value}")
best_params = study.best_params
print(f"Best hyperparameters: {study.best_params}")

#save_best_params(best_params=best_params, filename=f"{study_name}_best_params.json")
best_params["leak_rate"] = leak_rate
best_params["p"] = p
best_params["reservoir_units"] = reservoir_units
best_params["seed"] = seed
with open(f"{study_name}_best_params.json", "w") as f:
    json.dump(best_params, f, indent=4, default=convert_numpy)
# Out:
# [I 2026-03-03 11:05:48,660] A new study created in memory with name: esn_hypopt_study
# [I 2026-03-03 11:05:50,446] Trial 0 finished with value: -9.05086082531389 and parameters: {'spectral_radius': 0.10696039977048596, 'input_scaling': 0.40990353318043177, 'alpha': 4.51820592867273e-06}. Best is trial 0 with value: -9.05086082531389.
# [I 2026-03-03 11:05:52,336] Trial 1 finished with value: -0.452801148619678 and parameters: {'spectral_radius': 1.1873170439606548, 'input_scaling': 0.35235061163265063, 'alpha': 1.3110091548868583e-05}. Best is trial 0 with value: -9.05086082531389.
# [I 2026-03-03 11:05:54,062] Trial 2 finished with value: -3.994433298544483 and parameters: {'spectral_radius': 0.176148911117391, 'input_scaling': 0.30772822975984526, 'alpha': 0.00022068851820756757}. Best is trial 0 with value: -9.05086082531389.
# ...

# %%
from rcpy.models import create_model
from rcpy.training import train_model
from rcpy.forecasting import forecast_rcpy
from rcpy.analysis import compute_skill

best_params["seed"] = seed
best_params["reservoir_units"] = reservoir_units
best_params["leak_rate"] = leak_rate
best_params["p"] = p

best_model = create_model(hyperparams=best_params, output_dim=data['train_data'].shape[1])
best_model_trained = train_model(model=best_model, train_data=data['train_data'], forecasting_step=1, washout_training=train_config["washout_training"])

Y_pred = forecast_rcpy(
    model=best_model_trained,
    warmup_data=data['train_data'][-forecast_config["warmup_length"]:],
    forecast_length=val_length
)
val_skill = compute_skill(data["val_data"], Y_pred, method="efh", threshold=optimization["loss"]["threshold"], softness=optimization["loss"]["softness"])
print(f"Validation skill with best hyperparameters (SFH): {val_skill}")
# Out:
# Validation skill with best hyperparameters (SFH): 26.77795224303752

# %% [markdown]
# ## Best hyperparameters

# %%
import optuna
import matplotlib.pyplot as plt



best_params = study.best_params
print("Best hyperparameters found:")
for param, value in best_params.items():
    print(f"  {param}: {value}")

fig = optuna.visualization.plot_optimization_history(study)
#fig.update_yaxes(type='log')
fig.show()
# Out:
# Best hyperparameters found:
#   spectral_radius: 0.25806165365303585
#   input_scaling: 0.6936016354911116
#   alpha: 1.2492140100733612e-08

# %% [markdown]
# ## Performance

# %%
from rcpy.plotting import plot_forecast

forecast_length = data['val_data'].shape[0]
Y_true = data["val_data"][:forecast_length]
#Y_true = data["test_data"][:forecast_length]


# ================================
# 5a. PERFORMANCE
# ================================

# ----- Compute skill ----- 
efh_threshold = 0.1
efh_softness = 0.02
efh = compute_skill(y_true=Y_true, y_pred=Y_pred, method='efh', threshold=efh_threshold, softness=efh_softness)
vpt = compute_skill(y_true=Y_true, y_pred=Y_pred, method='vpt', threshold=0.2)
rmse_cumulative = compute_skill(y_true=Y_true, y_pred=Y_pred, method='error', mode="cumulative")
corr_cumulative = compute_skill(y_true=Y_true, y_pred=Y_pred, method='pearson', mode="cumulative")

# ----- Plot forecast -----
plot_cutoff = 35
fig = plot_forecast(Y_pred=Y_pred, Y_true=Y_true, efh=efh, rmse_cumulative=rmse_cumulative, corr_cumulative=corr_cumulative, plot_cutoff=plot_cutoff)
fig.get_axes()[0].axvline(vpt, color='red', linestyle='--', label=f'VPT: {vpt:.2f}')
fig.get_axes()[0].legend()
